# %%
import warnings
from crimm import fetch_rcsb
from crimm.StructEntities.OrganizedModel import OrganizedModel
from crimm.Modeller.Solvator import Solvator

from crimm.Fetchers import fetch_rcsb
from crimm.Modeller import TopologyGenerator
from crimm.Modeller.CoordManipulator import CoordManipulator
from crimm.Modeller.LoopBuilder import ChainLoopBuilder
from crimm.Adaptors.PropKaAdaptors import PropKaProtonator
from crimm.Utils.StructureUtils import get_coords

import pycharmm
from pycharmm.settings import set_verbosity as pcm_set_verbosity
from pycharmm import write as pcm_write
from pycharmm import NonBondedScript

from crimm.Adaptors.pyCHARMMAdaptors import (
    load_chain, load_topology, load_water, load_ions, load_ligands,
    create_water_hs_from_charmm, fetch_coords_from_charmm, patch_disu_from_model,
    sd_minimize
)

import pycharmm.minimize as minimize
import pycharmm.energy as energy
from pycharmm import coor, crystal, image, cons_harm, cons_fix, generate

# %%
# cgenff excutable path is used later in topology generation
CGENFF_PATH = "/export/app/cgenff/silcsbio.2024.1/cgenff/cgenff"
PDBID = '5igv' #'5iev'#'1bg8' #'3q4k' #'4pti' #'2HZI'

# %% [markdown]
# ## Fetch from RCSB
#
# The fetch_rcsb has be updated that it takes argument `organize`. When it is `True`, the structure will be organized into chain types, and an `OrganizedModel` will be returned instead of the unorganized structure entity.

# %%
model = fetch_rcsb(
    PDBID,
    include_solvent=True, # We want to incude crystallographic water
    use_bio_assembly=True,
    organize=True
)
# Out:
# /home/truman/crimm/crimm/StructEntities/Model.py:110: UserWarning: Chain F is a solvent chain, connect atom assignment skipped!
#   warnings.warn(
# /home/truman/crimm/crimm/StructEntities/Model.py:84: UserWarning: Insufficient atoms for connect record metalc
#   warnings.warn(
# /home/truman/crimm/crimm/StructEntities/Model.py:110: UserWarning: Chain E is a solvent chain, connect atom assignment skipped!
#   warnings.warn(
# /home/truman/crimm/crimm/StructEntities/Model.py:84: UserWarning: Insufficient atoms for connect record metalc
#   warnings.warn(
# /home/truman/crimm/crimm/StructEntities/Model.py:116: UserWarning: Residue None not found in chain A
#   warnings.warn(
# /home/truman/crimm/crimm/StructEntities/Model.py:99: UserWarning: Chain F not found in model 1
#   warnings.warn(

# %%
## the OrganinzedModel is improved with more feature and APIs
## and has become the main object that deals with modeling and interfacing pyCHARMM
## There will be another notebook showcasing more about OrganizedModel
model
# Out:
# NGLWidget()
# <OrganizedModel model=5IGV Polypeptide(L)=1 Solvent=1 NucleosidePhosphate=1 Ligand=1 Ion=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=298>
# 	├──────Description: Macrolide 2'-phosphotransferase II
# 	│
# 	├───<NucleosidePhosphate id=B Molecules=1>
# 	├──────Residue ID(s): GDP
# 	├──────Description: GUANOSINE-5'-DIPHOSPHATE
# 	│
# 	├───<Ligand id=C Molecules=1>
# 	├──────Residue ID(s): ZIT
# 	├──────Description: AZITHROMYCIN
# 	│
# 	├───<Ion id=D Residues=2>
# 	├──────Residue ID(s): CA, MG
# 	├──────Description: MAGNESIUM ION, CALCIUM ION
# 	│
# 	├───<Solvent id=E Residues=456>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water

# %%
## Place the model center to (0, 0, 0) and place the principle axis along x-axis
coord_man = CoordManipulator()
coord_man.load_entity(model)
coord_man.orient_coords()

# %%
model
# Out:
# NGLWidget()
# <OrganizedModel model=5IGV Polypeptide(L)=1 Solvent=1 NucleosidePhosphate=1 Ligand=1 Ion=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=298>
# 	├──────Description: Macrolide 2'-phosphotransferase II
# 	│
# 	├───<NucleosidePhosphate id=B Molecules=1>
# 	├──────Residue ID(s): GDP
# 	├──────Description: GUANOSINE-5'-DIPHOSPHATE
# 	│
# 	├───<Ligand id=C Molecules=1>
# 	├──────Residue ID(s): ZIT
# 	├──────Description: AZITHROMYCIN
# 	│
# 	├───<Ion id=D Residues=2>
# 	├──────Residue ID(s): CA, MG
# 	├──────Description: MAGNESIUM ION, CALCIUM ION
# 	│
# 	├───<Solvent id=E Residues=456>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water

# %%
model['B']
# Out:
# NGLWidget()
# <NucleosidePhosphate id=B Molecules=1>
#   Residue ID(s): GDP
#   Description: GUANOSINE-5'-DIPHOSPHATE

# %%
# build missing loops if exist
for chain in model.protein:
    if not chain.is_continuous():
        # chain can be built in place now by specifying `inplace = True`
        looper = ChainLoopBuilder(chain, inplace = True)
        # looper.build_from_homology(max_num_match=10, identity_score_cutoff=0.95)
        # missing terminals will also be built if `include_terminal = True`
        looper.build_from_alphafold(include_terminal = False)

# %%
chain.is_continuous()
# Out:
# True

# %% [markdown]
# ## Generate Topology
#
# Topology generation is simplified by using organized model. If `cgenff_path` is specified, ligands are also generated

# %%
topo = TopologyGenerator(
    cgenff_excutable_path=CGENFF_PATH,
    cgenff_output_path='./cgenff/'
)
topo.generate_model(
    model,
    prot_first_patch='ACE',
    prot_last_patch='CT3',
    coerce=True
)
# Out:
# /home/truman/crimm/crimm/Modeller/TopoLoader.py:738: UserWarning: No cmap found in <Polypeptide(L) id=A Residues=298>.
#   warnings.warn(

# %% [markdown]
# ### Printing out the TOPPAR and their Versions Being Used and Loaded

# %%
for rtf_type, topo_loader in topo.res_def_dict.items():
    print(rtf_type, 'toppar version:', topo_loader.rtf_version)
# Out:
# cgenff toppar version: 36.1
# protein toppar version: 36.2
# water_ions toppar version: 31.1

# %%
TopologyGenerator?
# Out:
# Init signature: TopologyGenerator(cgenff_excutable_path=None, cgenff_output_path=None)
# Docstring:
# Class for generating topology elements from the topology definition
# and parameters.
# The topology definition the parameters are loaded from the CHARMM 36 RTF and
# PRM files.
# If the cgenff_excutable_path is provided, the topology definition and
# parameters for the heterogen residues are generated by cgenff, and ligand mol2
# file and cgenff rtf file will be saved if cgenff_output_path is specified.
# Init docstring: Initialize the topology generator.
# File:           ~/crimm/crimm/Modeller/TopoLoader.py
# Type:           type
# Subclasses:

# %%
# Organized model
model
# Out:
# NGLWidget()
# <OrganizedModel model=5IGV Polypeptide(L)=1 Solvent=1 NucleosidePhosphate=1 Ligand=1 Ion=1 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=298>
# 	├──────Description: Macrolide 2'-phosphotransferase II
# 	│
# 	├───<NucleosidePhosphate id=B Molecules=1>
# 	├──────Residue ID(s): GDP
# 	├──────Description: GUANOSINE-5'-DIPHOSPHATE
# 	│
# 	├───<Ligand id=C Molecules=1>
# 	├──────Residue ID(s): ZIT
# 	├──────Description: AZITHROMYCIN
# 	│
# 	├───<Ion id=D Residues=2>
# 	├──────Residue ID(s): CA, MG
# 	├──────Description: MAGNESIUM ION, CALCIUM ION
# 	│
# 	├───<Solvent id=E Residues=456>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water

# %% [markdown]
# Modified residue creates breaks in chain after coersion

# %%
# Protonation 
protonator = PropKaProtonator(topo, pH = 7.4)
protonator.load_model(model)
# if there is any pathching applied in crimm, CHARMM PATCH command will be automatically run 
# when protein chains are loaded into CHARMM
protonator.apply_patches()
# Out:
# Unexpected number (9) of atoms in residue SER   2 A   in conformation 1A
# Unexpected number (9) of atoms in residue VAL 299 A   in conformation 1A
# No protonation patches to apply on chain A.

# %%
## All the topology definition and parameter generated for the model is 
## organized in model.topology_loader. load_topology() takes care of 
## loading sequence and only loads what is need for the model
load_topology(model.topology_loader)
# Out:
#
#  CHARMM>     read rtf card -
#  CHARMM>     name /tmp/tmpbrra2oyk
#  VOPEN> Attempting to open::/tmp/tmpbrra2oyk::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> * PROTEIN RTF LOADED FROM CRIMM
#  TITLE> 36  2
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name /tmp/tmpf_p5gqzk -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/tmp/tmpf_p5gqzk::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> * PROTEIN PRM LOADED FROM CRIMM
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> JAN. 2016 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name /tmp/tmpkonq5khr -
#  CHARMM>     append
#  VOPEN> Attempting to open::/tmp/tmpkonq5khr::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> * CGENFF RTF LOADED FROM CRIMM
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *          CGENFF: TOPOLOGY FOR THE CHARMM GENERAL FORCE FIELD V. 4.6          *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *
#
#  DRUDES PARTICLES WILL BE GENERATED AUTOMATICALLY FOR ALL ATOMS WITH NON-ZERO ALPHA
#  Thole-type dipole screening, Slater-Delta shape {S(u) = 1 - (1+u/2)*exp(-u)}, default radius =  1.300000
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name /tmp/tmp9l7y5eye -
#  CHARMM>     append -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/tmp/tmp9l7y5eye::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> * CGENFF PRM LOADED FROM CRIMM
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *         CGENFF: PARAMETERS FOR THE CHARMM GENERAL FORCE FIELD V. 4.6         *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *  2017/8: IF PROTEIN, NUCLEIC ACID AND CARBOHYDRATE TOPOLOGY AND PARAMETER FILES
#  TITLE> *  ARE NOT READ PRIOR TO THE CGENFF FILES "WARNING: ATOMS IN NBFIX ' errors will
#  TITLE> *  BE ENCOUNTERED.  THESE CAN BE PASSED BY SETTING BOMLEV ( -2) PRIOR TO READING
#  TITLE> *  THIS FILE. IN ADDITION, WHEN GENERATING AROMATIC HALOGENS (CL, BR, I) WITH
#  TITLE> *  PRE C41B/C42A VERSIONS OF CHARMM "MISSING PARAMETER" ERRORS WILL BE
#  TITLE> *  ENCOUNTERED THAT ALSO REQUIRE SETTING BOMLEV ( -2).
#  TITLE> *
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L CLGR   -3.60000   3.18000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L BRGR   -3.65000   3.33000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  CLGR   -0.40000   3.88000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  BRGR   -0.30000   4.05000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C BRGR   -0.27000   3.52000 DONT EXIST
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     stream /tmp/tmpswbor9sr
#  VOPEN> Attempting to open::/tmp/tmpswbor9sr::
#  OPNLGU> Unit 99 opened for READONLY access to /tmp/tmpswbor9sr
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * CGENFF TOPPAR FOR ZIT LOADED FROM CRIMM
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 3.0
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.6
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 3.0
#  RDTITL> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 3.0
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
#
#
#  CHARMM>     stream /tmp/tmpzrzytwl6
#  VOPEN> Attempting to open::/tmp/tmpzrzytwl6::
#  OPNLGU> Unit 99 opened for READONLY access to /tmp/tmpzrzytwl6
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * CGENFF TOPPAR FOR GDP LOADED FROM CRIMM
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 3.0
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.6
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 3.0
#  RDTITL> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 3.0
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
#
#
#  CHARMM>     stream /tmp/tmpy0qz3q5z
#  VOPEN> Attempting to open::/tmp/tmpy0qz3q5z::
#  OPNLGU> Unit 99 opened for READONLY access to /tmp/tmpy0qz3q5z
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * WATER ION TOPPAR LOADED FROM CRIMM
#  RDTITL> * TOPLOGY AND PARAMETER INFORMATION FOR WATER AND IONS.
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    !Testcase
#  CHARMM>    !test_water_ions.inp
#  CHARMM>
#
#  CHARMM>    ! IMPORTANT NOTE: this file contains NBFixes between carboxylates and sodium,
#  CHARMM>    ! which will only apply if the main files containing carboxylate atom types
#  CHARMM>    ! have been read in first!
#  CHARMM>
#
#  CHARMM>    !references
#  CHARMM>    !
#  CHARMM>    !TIP3P water model
#  CHARMM>    !
#  CHARMM>    !W.L. Jorgensen; J.Chandrasekhar; J.D. Madura; R.W. Impey;
#  CHARMM>    !M.L. Klein; "Comparison of simple potential functions for
#  CHARMM>    !simulating liquid water", J. Chem. Phys. 79 926-935 (1983).
#  CHARMM>    !
#  CHARMM>    !IONS
#  CHARMM>    !
#  CHARMM>    !Ions from Roux and coworkers
#  CHARMM>    !
#  CHARMM>    !Beglov, D. and Roux, B., Finite Representation of an Infinite
#  CHARMM>    !Bulk System: Solvent Boundary Potential for Computer Simulations,
#  CHARMM>    !Journal of Chemical Physics, 1994, 100: 9050-9063
#  CHARMM>    !
#  CHARMM>    !ZINC
#  CHARMM>    !
#  CHARMM>    !Stote, R.H. and Karplus, M. Zinc Binding in Proteins and
#  CHARMM>    !Solution: A Simple but Accurate Nonbonded Representation, PROTEINS:
#  CHARMM>    !Structure, Function, and Genetics 23:12-31 (1995)
#  CHARMM>
#
#  CHARMM>    !test "append" to determine if previous toppar files have been read and
#  CHARMM>    !add append to "read rtf card" if true
#  CHARMM>    set nat ?NATC
#  RDCMND substituted energy or value "?NATC" to "215"
#  Parameter: NAT <- "215"
#
#  CHARMM>    set app
#  Parameter: APP <- "" <empty>
#
#  CHARMM>    !We're exploiting what is arguably a bug in the parser. On the left hand side,
#  CHARMM>    !the quotes have priority, so NAT is correctly substituted. On the right hand
#  CHARMM>    !side, the ? has priority and NATC" (sic) is not a valid substitution...
#  CHARMM>    if "@NAT" ne "?NATC" if @nat ne 0 set app append
#  Parameter: NAT -> "215"
#  Parameter: NAT -> "215"
#  RDCMND: can not substitute energy "?NATC""
#  Comparing ""215"" and ""?NATC"".
#  IF test evaluated as true.  Performing command
#  Comparing "215" and "0".
#  IF test evaluated as true.  Performing command
#  Parameter: APP <- "APPEND"
#
#  CHARMM>
#
#  CHARMM>    read rtf card @app
#  Parameter: APP -> "APPEND"
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGY FOR WATER AND IONS
#  RDTITL> *
#
#  CHARMM>
#
#  CHARMM>    read para card flex @app
#  Parameter: APP -> "APPEND"
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS FOR WATER AND IONS
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>
#
#  CHARMM>    ! The following section contains NBFixes for sodium interacting with
#  CHARMM>    ! carboxylate oxygens of various CHARMM force fields. It will generate
#  CHARMM>    ! level -1 warnings whenever any of these force fields have not been
#  CHARMM>    ! read prior to the current stream file. Since we don't want to force
#  CHARMM>    ! the user to always read all the force fields, we're suppressing the
#  CHARMM>    ! warnings. The only side effect is that you will have "most severe
#  CHARMM>    ! warning was at level 0" at the end of your output. Also note that
#  CHARMM>    ! the user is responsible for reading the current file last if they
#  CHARMM>    ! want the NBFixes to apply. A more elegant solution would require new
#  CHARMM>    ! features to be added to CHARMM.
#  CHARMM>    ! parallel fix, to avoid duplicated messages in the log
#  CHARMM>    set para
#  Parameter: PARA <- "" <empty>
#
#  CHARMM>    if ?NUMNODE gt 1 set para node 0
#  RDCMND substituted energy or value "?NUMNODE" to "1"
#  Comparing "1" and "1".
#  IF test evaluated as false.  Skipping command
#
#  CHARMM>
#
#  CHARMM>    set wrn ?WRNLEV
#  RDCMND substituted energy or value "?WRNLEV" to "5"
#  Parameter: WRN <- "5"
#
#  CHARMM>    ! Some versions of CHARMM don't seem to initialize wrnlev...
#  CHARMM>    if "@WRN" eq "?WRNLEV" set wrn 5
#  Parameter: WRN -> "5"
#  RDCMND: can not substitute energy "?WRNLEV""
#  Comparing ""5"" and ""?WRNLEV"".
#  IF test evaluated as false.  Skipping command
#
#  CHARMM>    set bom ?bomlev
#  RDCMND substituted energy or value "?BOMLEV" to "0"
#  Parameter: BOM <- "0"
#
#  CHARMM>    WRNLEV -1 @PARA
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>    BOMLEV -1 @PARA
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>    read para card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * NBFIX BETWEEN CARBOXYLATE AND SODIUM
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    BOMLEV @bom @PARA
#  Parameter: BOM -> "0"
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>    WRNLEV @wrn @PARA
#  Parameter: WRN -> "5"
#  Parameter: PARA -> "" <empty>
#
#  CHARMM>
#
#  CHARMM>    return
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90

# %%
for chain in model.protein:
    load_chain(chain)
# we need to patch disulfide bonds in CHARMM
# the disu info is stored in model under model.connect_dict
patch_disu_from_model(model)
# Out:
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmp8fil40tw
#  VOPEN> Attempting to open::/tmp/tmp8fil40tw::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --   298 RESIDUES
#           SER LYS ASP ILE LYS GLN VAL ILE GLU ILE ALA LYS LYS HSD ASN LEU PHE LEU LYS GLU
#           GLU THR ILE GLN PHE ASN GLU SER GLY LEU ASP PHE GLN ALA VAL PHE ALA GLN ASP ASN
#           ASN GLY ILE ASP TRP VAL LEU ARG LEU PRO ARG ARG GLU ASP VAL MET PRO ARG THR LYS
#           VAL GLU LYS GLN ALA LEU ASP LEU VAL ASN LYS TYR ALA ILE SER PHE GLN ALA PRO ASN
#           TRP ILE ILE TYR THR GLU GLU LEU ILE ALA TYR LYS LYS LEU ASP GLY VAL PRO ALA GLY
#           THR ILE ASP HSD ASN ILE GLY ASN TYR ILE TRP GLU ILE ASP ILE ASN ASN VAL PRO GLU
#           LEU PHE HSD LYS SER LEU GLY ARG VAL LEU ALA GLU LEU HSD SER ILE PRO SER ASN LYS
#           ALA ALA ALA LEU ASP LEU VAL VAL HSD THR PRO GLU GLU ALA ARG MET SER MET LYS GLN
#           ARG MET ASP ALA VAL ARG ALA LYS PHE GLY VAL GLY GLU ASN LEU TRP ASN ARG TRP GLN
#           ALA TRP LEU ASN ASP ASP ASP MET TRP PRO LYS LYS THR GLY LEU ILE HSD GLY ASP VAL
#           HSD ALA GLY HSD THR MET ILE ASP LYS ASP ALA ASN VAL THR GLY LEU ILE ASP TRP THR
#           GLU ALA LYS VAL THR ASP VAL SER HSD ASP PHE ILE PHE ASN TYR ARG ALA PHE GLY GLU
#           GLU GLY LEU GLU ALA LEU ILE LEU ALA TYR LYS GLU ILE GLY GLY TYR TYR TRP PRO LYS
#           MET LYS GLU HSD ILE ILE GLU LEU ASN ALA ALA TYR PRO VAL SER ILE ALA GLU PHE ALA
#           LEU VAL SER GLY ILE GLU GLU TYR GLU GLN MET ALA LYS GLU ALA LEU GLU VAL
#  ***** Message from SEQRDR ***** THE SYSTEM CONTAINS 89 TITRATABLE GROUPS
#  THE USER MUST PREDETERMINE THE PROTONATION STATE THROUGH THE SEQUENCE AND RTF
#  HIS -  0  HSD - 10  HSE -  0  HSP -  0  ASP - 20  GLU - 27  LYS - 22  TYR - 10
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  THE PATCH 'ACE' WILL BE USED FOR THE FIRST RESIDUE
#  THE PATCH 'CT3' WILL BE USED FOR THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  GENPSF> Segment   1 has been generated. Its identifier is PROA.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =      298
#          Number of atoms         =     4783   Number of groups     =     1417
#          Number of bonds         =     4841   Number of angles     =     8766
#          Number of dihedrals     =    12835   Number of impropers  =      839
#          Number of cross-terms   =      298   Number of autogens   =        0
#          Number of HB acceptors  =      459   Number of HB donors  =      506
#          Number of NB exclusions =        0   Total charge =  -15.00000
#  QXFORM> Expanded format used.
#          More than 4 character atom type used.
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmp8fil40tw -
#  CHARMM>     resi
#  VOPEN> Attempting to open::/tmp/tmp8fil40tw::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>

# %%
# model.ligand+model.phos_ligand+model.co_solvent is the concatenated list of entities
load_ligands(model.ligand+model.phos_ligand+model.co_solvent)
# load_ligands(model.ligand)
# Out:
# [crimm] Loading ligand ZIT SEG: LG00
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmp2rxi2ouz
#  VOPEN> Attempting to open::/tmp/tmp2rxi2ouz::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     1 RESIDUES
#           ZIT
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  GENPSF> Segment   2 has been generated. Its identifier is LG00.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        2   Number of residues   =      299
#          Number of atoms         =     4907   Number of groups     =     1418
#          Number of bonds         =     4967   Number of angles     =     9008
#          Number of dihedrals     =    13188   Number of impropers  =      840
#          Number of cross-terms   =      298   Number of autogens   =        0
#          Number of HB acceptors  =      459   Number of HB donors  =      506
#          Number of NB exclusions =        0   Total charge =  -15.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmp2rxi2ouz -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmp2rxi2ouz::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [crimm] Loading ligand GDP SEG: LG01
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpe0e0pslz
#  VOPEN> Attempting to open::/tmp/tmpe0e0pslz::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     1 RESIDUES
#           GDP
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  GENPSF> Segment   3 has been generated. Its identifier is LG01.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        3   Number of residues   =      300
#          Number of atoms         =     4950   Number of groups     =     1419
#          Number of bonds         =     5012   Number of angles     =     9084
#          Number of dihedrals     =    13299   Number of impropers  =      843
#          Number of cross-terms   =      298   Number of autogens   =        0
#          Number of HB acceptors  =      459   Number of HB donors  =      506
#          Number of NB exclusions =        0   Total charge =  -15.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmpe0e0pslz -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmpe0e0pslz::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
# ['LG00', 'LG01']

# %% [markdown]
# ## Minimize the Protein Chain First

# %%
# Specify nonbonded python object called my_nbonds - this just sets it up
# equivalant CHARMM scripting command: 
# nbonds cutnb 18 ctonnb 13 ctofnb 17 cdie eps 1 atom vatom fswitch vfswitch
non_bonded_script = NonBondedScript(
    cutnb=18.0, ctonnb=13.0, ctofnb=17.0,
    eps=1.0,
    cdie=True,
    atom=True, vatom=True,
    fswitch=True, vfswitch=True
)
# select the C-alpha atoms for harmonic restraints
cons_harm_atoms = pycharmm.SelectAtoms(atom_type='CA')
ener_dict = sd_minimize(300, non_bonded_script, cons_harm_selection=cons_harm_atoms)
# Out:
#
#  CHARMM>     nbonds cutnb 18.0 -
#  CHARMM>     ctonnb 13.0 -
#  CHARMM>     ctofnb 17.0 -
#  CHARMM>     eps 1.0 -
#  CHARMM>     cdie -
#  CHARMM>     atom -
#  CHARMM>     vatom -
#  CHARMM>     fswitch -
#  CHARMM>     vfswitch
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found  14096 exclusions and  13045 interactions(1-4)
#  <MAKGRP> found   4151 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3023098 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#  WARNING: ATOMS LG00     1        ZIT      H223     AND LG00     1        ZIT      HO13     ONLY 1.34 A. APART
#
#  General atom nonbond list generation found:
#   2985531 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    102192 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>
#
#  CSTRAN: Harmonic Restraints
#           ABSOlute type as set number  1.  Number of selected atoms:    298
#           Reference coordinates set to main coordinates.
#           Mass weighting will NOT be used for new restraints.
#           The force constant of      20.00000 will be used.
#           An exponent of  2 will be used.
#           The XYZ scale factors are:       1.00000       1.00000       1.00000
#           A total of    298 atoms are restrained.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are  2985531 atom  pairs and    27141 atom  exclusions.
#  There are        0 group pairs and     4151 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3023098 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#  WARNING: ATOMS LG00     1        ZIT      H223     AND LG00     1        ZIT      HO13     ONLY 1.34 A. APART
#
#  General atom nonbond list generation found:
#   2985531 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    102192 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
# /home/truman/crimm/crimm/Adaptors/pyCHARMMAdaptors.py:449: UserWarning: Absolute harmonic restraints setup success: True
#   warnings.warn(f"Absolute harmonic restraints setup success: {has_cons_harm}")
#  STEEPD> An energy minimization has been requested.
#
#  NSTEP  =          300   NPRINT =           10
#  STEP   =    0.0200000   TOLFUN =    0.0010000
#  TOLGRD =    0.0010000   TOLSTP =    0.0000000
#
# MINI MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# MINI INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# MINI CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# MINI EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>        0   -933.41905      0.00000     11.33272      0.02000
# MINI INTERN>      377.55480    796.66131    118.33669   2852.12949     58.68208
# MINI CROSS>       -77.30932      0.00000      0.00000      0.00000
# MINI EXTERN>     -468.70611  -4590.76800      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       10  -2175.21989   1241.80084      7.24970      0.00373
# MINI INTERN>      258.04828    753.43526     67.46251   2804.00497     45.32430
# MINI CROSS>      -117.12552      0.00000      0.00000      0.00000
# MINI EXTERN>    -1069.09459  -4919.35200      0.00000      0.00000      0.00000
# MINI CONSTR>        2.07690      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       20  -2476.28287    301.06297      2.75196      0.00167
# MINI INTERN>      219.14783    704.73975     68.12512   2795.69152     42.64099
# MINI CROSS>      -120.13701      0.00000      0.00000      0.00000
# MINI EXTERN>    -1155.82723  -5034.09233      0.00000      0.00000      0.00000
# MINI CONSTR>        3.42849      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       30  -2580.63185    104.34898      4.10705      0.00180
# MINI INTERN>      234.21324    737.15327     68.61111   2791.95261     42.93627
# MINI CROSS>      -123.29528      0.00000      0.00000      0.00000
# MINI EXTERN>    -1212.85701  -5124.05739      0.00000      0.00000      0.00000
# MINI CONSTR>        4.71134      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       40  -2667.73971     87.10786      3.91942      0.00193
# MINI INTERN>      239.28258    747.72671     69.08934   2789.67827     42.88201
# MINI CROSS>      -125.20706      0.00000      0.00000      0.00000
# MINI EXTERN>    -1246.90982  -5190.17696      0.00000      0.00000      0.00000
# MINI CONSTR>        5.89524      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step        50
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3023098 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.96 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#
#  General atom nonbond list generation found:
#   2983402 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    102279 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>       50  -2764.10987     96.37016      0.84847      0.00087
# MINI INTERN>      228.31166    742.35133     69.42159   2787.82649     42.81470
# MINI CROSS>      -126.67841      0.00000      0.00000      0.00000
# MINI EXTERN>    -1271.14632  -5244.02321      0.00000      0.00000      0.00000
# MINI CONSTR>        7.01230      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       60  -2831.00070     66.89083      1.08689      0.00093
# MINI INTERN>      235.13138    750.16218     69.60542   2785.94873     42.77324
# MINI CROSS>      -128.02418      0.00000      0.00000      0.00000
# MINI EXTERN>    -1293.87681  -5301.03190      0.00000      0.00000      0.00000
# MINI CONSTR>        8.31124      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       70  -2880.89482     49.89411      1.93978      0.00100
# MINI INTERN>      244.26603    756.48549     69.59062   2784.37668     42.75839
# MINI CROSS>      -129.05996      0.00000      0.00000      0.00000
# MINI EXTERN>    -1310.53122  -5348.26590      0.00000      0.00000      0.00000
# MINI CONSTR>        9.48505      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       
0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      290  -3439.03743     17.42539      0.36964      0.00035
# MINI INTERN>      268.09237    803.66939     70.18000   2771.84745     43.66826
# MINI CROSS>      -138.43682      0.00000      0.00000      0.00000
# MINI EXTERN>    -1393.93209  -5890.10898      0.00000      0.00000      0.00000
# MINI CONSTR>       25.98299      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Nonbond update at step       300
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3023098 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#
#  General atom nonbond list generation found:
#   2982601 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    102432 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      300  -3453.01198     13.97455      0.36128      0.00038
# MINI INTERN>      268.54610    804.44554     70.28278   2771.86291     43.61841
# MINI CROSS>      -138.69566      0.00000      0.00000      0.00000
# MINI EXTERN>    -1395.31085  -5904.23280      0.00000      0.00000      0.00000
# MINI CONSTR>       26.47158      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  STEEPD> Minimization exiting with number of steps limit (       300) exceeded.
#
# STPD MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# STPD INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# STPD CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# STPD EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# STPD CONSTR:       HARMonic    CDIHedral          CIC     RESDistance       NOE
#  ----------       ---------    ---------    ---------    ---------    ---------
# STPD>      300  -3453.01198     13.97455      0.36128      0.00046
# STPD INTERN>      268.54610    804.44554     70.28278   2771.86291     43.61841
# STPD CROSS>      -138.69566      0.00000      0.00000      0.00000
# STPD EXTERN>    -1395.31085  -5904.23280      0.00000      0.00000      0.00000
# STPD CONSTR>       26.47158      0.00000      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 18.000 CTEXNB =999.000 CTONNB = 13.000 CTOFNB = 17.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are  2982601 atom  pairs and    27141 atom  exclusions.
#  There are        0 group pairs and     4151 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  3023098 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#
#  General atom nonbond list generation found:
#   2982601 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    102432 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0  -3479.48356     26.47158      0.53034
# ENER INTERN>      268.54610    804.44554     70.28278   2771.86291     43.61841
# ENER CROSS>      -138.69566      0.00000      0.00000      0.00000
# ENER EXTERN>    -1395.31085  -5904.23280      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------

# %% [markdown]
# ## Sync Coord with pyCHARMM
# We need to update the coords of crimm protein after minimization

# %%
## This is the new API for crimm sync coordinates with CHARMM
## The old sync_coord only works in a limited number of situations thus is DEPRECATED
fetch_coords_from_charmm(model.protein+model.ligand+model.phos_ligand+model.co_solvent)

# %% [markdown]
# ## Solvation

# %%
solvator = Solvator(model)
# we want to keep the crystallograpic water using remove_existing_water=False
# doc string available for Solvator and
added_water = solvator.solvate(
    cutoff=8.0, solvcut=2.1, remove_existing_water=False, orient_coords=False
)
# Solvator.add_balancing_ions will add either sodium (SOD) or chloride (CLA)
# to the solvent according to the total charge of the system
balancing_ion_chain = solvator.add_balancing_ions()
# Out:
# Total charges before adding ions: -11.0
#   [Chain A] -15.0
#   [Chain B] 0.0
#   [Chain C] 0.0
#   [Chain D] 4.0

# %% [markdown]
# ## Doc Strings for Solvator

# %%
Solvator?
# Out:
# Init signature: Solvator(entity) -> None
# Docstring:
# Solvates a Structure, Model, or Chain level entity with water molecules.
# The solvated entity will be returned as a Model level entity. The solvated
# entity will be centered in a cubic box with side length equal to the
# maximum dimension of the entity plus the cutoff distance. (i.e., Coordinates
# will be oriented using CoordManipulator.orient_coords() before solvation.)
# The solvcut distance is the distance from the solute at which water
# molecules will be removed. The solvcut distance is used to remove water
# molecules that are too close to the solute.
# If altloc atoms exist in the entity, the first altloc atoms will be used to
# determine water molecules location during solvation.
#
# Parameters
# ----------
# entity : Structure, Model, or Chain level entity
#     The entity to solvate. If a Structure level entity is provided, the
#     first Model will be solvated. If a Model level entity is provided, all
#     chains in the model will be solvated. If a Chain level entity is
#     provided, the chain will be solvated. The entity is modified in place.
#
# Examples
# --------
# >>> from crimm import fetch_rcsb
# >>> from crimm.Modeller.Solvator import Solvator
#
# >>> fisrt_model = fetch_rcsb('5igv')
# >>> solvator = Solvator()
# >>> solvated_model = solvator.solvate(
#         fisrt_model, cutoff=8.0, solvcut=2.1, remove_existing_water=True
#     )
# >>> water_chains = [
#     chain for chain in solvated if chain.chain_type == 'Solvent'
# ]
#
# Note that water chains are named W[A-Z] and have a maximum number of 9999 residues
# >>> water_chains
# [<Solvent id=WA Residues=9999>, <Solvent id=WB Residues=2486>]
# >>> solvator.water_box_coords.shape # shape in (N waters, 3 atoms, 3 coords)
# (12485, 3, 3)
# >>> chain = structure[1]['A'] # get chain A from the first model
# >>> solvated_chain = solvator.solvate(chain)
#
# More water molecules are added to solvate the chain since the ligands are
# not included in the solvation process
# >>> solvator.water_box_coords.shape
# (12531, 3, 3)
# File:           ~/crimm/crimm/Modeller/Solvator.py
# Type:           type
# Subclasses:

# %%
Solvator.solvate?
# Out:
# Signature:
# Solvator.solvate(
#     self,
#     cutoff=9.0,
#     solvcut=2.1,
#     remove_existing_water=True,
#     orient_coords=True,
# ) -> crimm.StructEntities.Model.Model
# Docstring:
# Solvates the entity and returns a Model level entity. The solvated
# entity will be centered in a cubic box with side length equal to the
# maximum dimension of the entity plus the cutoff distance. (i.e.,
# Coordinates will be oriented using CoordManipulator.orient_coords()
# before solvation.) The solvcut distance is the distance from the solute
# at which water molecules will be removed. The solvcut distance is used
# to remove water molecules that are too close to the solute. If altloc
# atoms exist in the entity, the first altloc atoms will be used to
# determine water molecules location during solvation.
#
# Parameters
# ----------
# cutoff : float, optional
#     The distance from the solute to the edge of the cubic box. The
#     default is 9.0.
# solvcut : float, optional
#     The distance from the solute at which water molecules will be
#     removed. The default is 2.10.
# remove_existing_water : bool, optional
#     If True, remove existing water molecules from the entity. The default
#     is True.
# File:      ~/crimm/crimm/Modeller/Solvator.py
# Type:      function

# %%
Solvator.add_balancing_ions?
# Out:
# Signature:
# Solvator.add_balancing_ions(
#     self,
#     present_charge=None,
#     cation='SOD',
#     anion='CLA',
#     skip_undefined=True,
# ) -> crimm.StructEntities.Chain.Ion
# Docstring:
# Add balancing ions to the solvated entity to bring total charge to zero.
# The default cation is Na+ and the default anion is Cl-. If the entity is
# not a solvated entity, a ValueError will be raised. A random selection of
# water molecules in the water box will be replaced with balancing ions.
# Returns a chain containing the balancing ions.
#
# Parameters
# ----------
# entity : Structure, Model, or Chain level entity
#     The solvated entity to add balancing ions to.
# present_charge : int, optional
#     The present charge of the solvated entity. If None, the charge will be
#     calculated from the entity. The default is None. If for any reason you
#     want to balance the charge to a non-zero value, you can specify it here.
# cation : str, optional
#     The cation to use. The default is 'SOD' (Na+).
# anion : str, optional
#     The anion to use. The default is 'CLA' (Cl-).
#
# Returns
# -------
# ion_chain : Chain
#     A chain containing the balancing ions.
# File:      ~/crimm/crimm/Modeller/Solvator.py
# Type:      function

# %% [markdown]
# ## Model after Solvation
#
# Note that we have added 4 chloride ions as chain IA since the total charge was **+4**.<br>
# The water box has to be splitted into two chains due to PDB residue number limit to **9999**.

# %%
model
# Out:
# NGLWidget()
# <OrganizedModel model=5IGV Polypeptide(L)=1 Solvent=3 NucleosidePhosphate=1 Ligand=1 Ion=2 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=298>
# 	├──────Description: Macrolide 2'-phosphotransferase II
# 	│
# 	├───<NucleosidePhosphate id=B Molecules=1>
# 	├──────Residue ID(s): GDP
# 	├──────Description: GUANOSINE-5'-DIPHOSPHATE
# 	│
# 	├───<Ligand id=C Molecules=1>
# 	├──────Residue ID(s): ZIT
# 	├──────Description: AZITHROMYCIN
# 	│
# 	├───<Ion id=D Residues=2>
# 	├──────Residue ID(s): CA, MG
# 	├──────Description: MAGNESIUM ION, CALCIUM ION
# 	│
# 	├───<Solvent id=E Residues=455>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water
# 	│
# 	├───<Solvent id=WA Residues=9992>
# 	├──────Description: water
# 	│
# 	├───<Solvent id=WB Residues=2560>
# 	├──────Description: water
# 	│
# 	├───<Ion id=IA Residues=11>
# 	├──────Description: balancing ions (SOD)

# %% [markdown]
# ## Load other Entities into CHARMM
# Currently Ligand, Nucleophosphate, and CoSolvent can be automatically generated by TopologyLoader. <br>
# Thus, if they exist, they can be safely loaded into CHARMM

# %%
load_ions(model.ion)
# This loads both crystallographic water and the water box generated by Solvator
load_water(model.solvent)
# Since crimm cannot build hydrogens on the crystallographic water yet
# we will build them in CHARMM and copy their coords to crimm
create_water_hs_from_charmm(model)
# Out:
# [crimm] Loading ion chain IO00
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpdf599gtu
#  VOPEN> Attempting to open::/tmp/tmpdf599gtu::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     2 RESIDUES
#           MG      CAL
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   4 has been generated. Its identifier is IO00.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        4   Number of residues   =      302
#          Number of atoms         =     4952   Number of groups     =     1421
#          Number of bonds         =     5012   Number of angles     =     9084
#          Number of dihedrals     =    13299   Number of impropers  =      843
#          Number of cross-terms   =      298   Number of autogens   =        0
#          Number of HB acceptors  =      459   Number of HB donors  =      506
#          Number of NB exclusions =        0   Total charge =  -11.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmpdf599gtu -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmpdf599gtu::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [crimm] Loading ion chain IO01
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmp8soqmoys
#  VOPEN> Attempting to open::/tmp/tmp8soqmoys::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --    11 RESIDUES
#           SOD     SOD     SOD     SOD     SOD     SOD     SOD     SOD     SOD     SOD     SOD
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   5 has been generated. Its identifier is IO01.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        5   Number of residues   =      313
#          Number of atoms         =     4963   Number of groups     =     1432
#          Number of bonds         =     5012   Number of angles     =     9084
#          Number of dihedrals     =    13299   Number of impropers  =      843
#          Number of cross-terms   =      298   Number of autogens   =        0
#          Number of HB acceptors  =      459   Number of HB donors  =      506
#          Number of NB exclusions =        0   Total charge =   -0.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmp8soqmoys -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmp8soqmoys::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [crimm] Loading water chain WT00
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpzwrk08er
#  VOPEN> Attempting to open::/tmp/tmpzwrk08er::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --   455 RESIDUES
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   6 has been generated. Its identifier is WT00.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        6   Number of residues   =      768
#          Number of atoms         =     6328   Number of groups     =     1887
#          Number of bonds         =     6377   Number of angles     =     9539
#          Number of dihedrals     =    13299   Number of impropers  =      843
#          Number of cross-terms   =      298   Number of autogens   =        0
#          Number of HB acceptors  =      914   Number of HB donors  =     1416
#          Number of NB exclusions =        0   Total charge =   -0.00000
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /tmp/tmpzwrk08er -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/tmp/tmpzwrk08er::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4965   314 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4966   314 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4968   315 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4969   315 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4971   316 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4972   316 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4974   317 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4975   317 TIP3 H2
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4977   318 TIP3 H1
#  ** WARNING ** After reading, there are no coordinates for selected atom:  4978   318 TIP3 H2
#
#  ** A total of   910 selected atoms have no coordinates
#  *** LEVEL  2 WARNING *** BOMLEV IS    0
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
# [crimm] Loading water chain WT01
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /tmp/tmpjigdiy4j
#  VOPEN> Attempting to open::/tmp/tmpjigdiy4j::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --  9992 RESIDUES
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
#           TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3    TIP3
# ...
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     173      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.79529 A.
#
#  NBONDX:      4128 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     157      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.79996 A.
#
#  NBONDX:      4682 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     217      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.80739 A.
#
#  NBONDX:      4756 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     435      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.80885 A.
#
#  NBONDX:      4744 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     340      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.81761 A.
#
#  NBONDX:      2988 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     383      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.82242 A.
#
#  NBONDX:      4824 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     203      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.82381 A.
#
#  NBONDX:      4708 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     453      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.82936 A.
#
#  NBONDX:      4656 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     222      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.83239 A.
#
#  NBONDX:      4008 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     385      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.83752 A.
#
#  NBONDX:      4840 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     398      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.84022 A.
#
#  NBONDX:      4790 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     193      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.84426 A.
#
#  NBONDX:      4628 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     335      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.84477 A.
#
#  NBONDX:      4472 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     445      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.84539 A.
#
#  NBONDX:      4840 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     254      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.84881 A.
#
#  NBONDX:      4912 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     267      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.85259 A.
#
#  NBONDX:      4850 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     264      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.85360 A.
#
#  NBONDX:      4840 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     296      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.86332 A.
#
#  NBONDX:      4622 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     371      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.86356 A.
#
#  NBONDX:      4782 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     407      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.86566 A.
#
#  NBONDX:      4828 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     302      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.86792 A.
#
#  NBONDX:      3782 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     436      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.87093 A.
#
#  NBONDX:      4856 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     216      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.87592 A.
#
#  NBONDX:      4858 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     431      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.88589 A.
#
#  NBONDX:      4500 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     360      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.88611 A.
#
#  NBONDX:      4898 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     359      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.88753 A.
#
#  NBONDX:      4656 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     226      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.88871 A.
#
#  NBONDX:      4886 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     58       TIP3     OH2     .
#  Minimum distance between this water and protein is  2.89404 A.
#
#  NBONDX:      4774 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     388      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.89458 A.
#
#  NBONDX:      4914 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     202      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.89522 A.
#
#  NBONDX:      4772 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     424      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.90476 A.
#
#  NBONDX:      4808 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     169      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.91129 A.
#
#  NBONDX:      5022 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     372      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.91389 A.
#
#  NBONDX:      4730 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     300      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.92081 A.
#
#  NBONDX:      4876 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     415      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.93692 A.
#
#  NBONDX:      4764 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     260      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.93986 A.
#
#  NBONDX:      4728 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     352      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.95193 A.
#
#  NBONDX:      4660 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     102      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.95481 A.
#
#  NBONDX:      4734 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     451      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.96555 A.
#
#  NBONDX:      4566 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     235      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.96915 A.
#
#  NBONDX:      4856 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     413      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.97056 A.
#
#  NBONDX:      4808 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     450      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.97198 A.
#
#  NBONDX:      4928 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     404      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.98559 A.
#
#  NBONDX:      4884 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     253      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.98981 A.
#
#  NBONDX:      4764 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     346      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.99116 A.
#
#  NBONDX:      4668 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     366      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.99151 A.
#
#  NBONDX:      4764 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     444      TIP3     OH2     .
#  Minimum distance between this water and protein is  2.99263 A.
#
#  NBONDX:      4832 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     382      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.00028 A.
#
#  NBONDX:      4760 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     286      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.00993 A.
#
#  NBONDX:      4790 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     290      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.01552 A.
#
#  NBONDX:      4802 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     344      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.04719 A.
#
#  NBONDX:      4856 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     327      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.07451 A.
#
#  NBONDX:      4920 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     313      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.07861 A.
#
#  NBONDX:      4962 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     391      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.09002 A.
#
#  NBONDX:      4728 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     448      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.09324 A.
#
#  NBONDX:      5162 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     376      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.10237 A.
#
#  NBONDX:      4902 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     429      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.11153 A.
#
#  NBONDX:      4818 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     367      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.11591 A.
#
#  NBONDX:      4860 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     403      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.13557 A.
#
#  NBONDX:      4926 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     454      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.13887 A.
#
#  NBONDX:      4978 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     299      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.15019 A.
#
#  NBONDX:      4750 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     440      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.17626 A.
#
#  NBONDX:      4912 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     224      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.18446 A.
#
#  NBONDX:      4854 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     400      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.21937 A.
#
#  NBONDX:      4808 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     446      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.30669 A.
#
#  NBONDX:      4780 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     320      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.32603 A.
#
#  NBONDX:      4910 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     347      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.33913 A.
#
#  NBONDX:      4934 atom and      0 group interactions within 18.00 A.
#  Spin:H1      ,H2      ,        ,         constructed for water WT00     409      TIP3     OH2     .
#  Minimum distance between this water and protein is  3.67098 A.

# %%
# We can visualize the crystallographic water and see the hydrogens are added
model.solvent[0]
# Out:
# NGLWidget()
# <Solvent id=E Residues=455>
#   Residue ID(s): HOH
#   Description: water

# %% [markdown]
# ## Set up PBC and Minimize Water

# %%
# organize segids and ion types for image and cons_fix
non_solvent_segids = set()
all_ion_types = set()
for chain in model:
    if chain.chain_type == 'Solvent':
        continue
    elif chain.chain_type == 'Ion':
        for res in chain:
            all_ion_types.add(res.resname)
    else:
        for res in chain:
            non_solvent_segids.add(res.segid)

# %%
# anything but solvent or ions in the model
non_solvent_segids
# Out:
# {'LG00', 'LG01', 'PROA'}

# %%
# all types of ions loaded in pyCHARMM by crimm
all_ion_types
# Out:
# {'CAL', 'MG', 'SOD'}

# %%
# CHARMM scripting: crystal define cubic @boxsize @boxsize @boxsize 90 90 90
crystal.define_cubic(solvator.box_dim)
# CHARMM scripting: crystal build cutoff @boxhalf noper 0
crystal.build(solvator.box_dim/2)
# Out:
#  Crystal Parameters : Crystal Type = CUBI
#            A     =   77.04339 B    =   77.04339 C     =   77.04339
#            Alpha =   90.00000 Beta =   90.00000 Gamma =   90.00000
#  XBUILD> Building all transformations with a minimum atom-atom
#          contact distance of less than   38.52 Angstroms.
#
#  Range of Grid Search for Transformation     1 :
#  Lattice Vector A    -2 TO     2
#  Lattice Vector B    -2 TO     2
#  Lattice Vector C    -2 TO     2
#
#
#  The number of transformations generated =    26
#
#
#  Number  Symop   A   B   C   Distance
#
#       1      1  -1  -1  -1     2.6826
#       2      1  -1   0  -1     2.0953
#       3      1  -1   1  -1     3.3216
#       4      1   0  -1  -1     2.4960
#       5      1   0   0  -1     1.6094
#       6      1   0   1  -1     2.7724
#       7      1  -1  -1   0     2.4622
#       8      1  -1   0   0     1.8045
#       9      1  -1   1   0     3.0165
#      10      1   0  -1   0     1.6793
#      11      1   0   1   0     1.6793
#      12      1  -1  -1   1     3.5658
#      13      1  -1   0   1     2.0755
#      14      1  -1   1   1     4.0914
#      15      1   0  -1   1     2.7724
#      16      1   0   0   1     1.6094
#      17      1   0   1   1     2.4960
#      18      1   1   1   1     2.6826
#      19      1   1   0   1     2.0953
#      20      1   1  -1   1     3.3216
#      21      1   1   1   0     2.4622
#      22      1   1   0   0     1.8045
#      23      1   1  -1   0     3.0165
#      24      1   1   1  -1     3.5658
#      25      1   1   0  -1     2.0755
#      26      1   1  -1  -1     4.0914
#                      THERE ARE NO ROTATIONS FOR THIS TRANSFORMATION SET
#     26 Transformations have been processed.
# 1

# %%
# Turn on image centering - bysegment for protein, by residue for solvent and ions
# CHARMM scripting: image byseg xcen 0 ycen 0 zcen 0 select segid SEGID end
for segid in non_solvent_segids:
    image.setup_segment(0.0, 0.0, 0.0, segid)
# CHARMM scripting: image byres xcen 0 ycen 0 zcen 0 select resname tip3 end
image.setup_residue(0.0, 0.0, 0.0, 'TIP3')
# CHARMM scripting: image byres xcen 0 ycen 0 zcen 0 select resname ion_type end
for ion_type in all_ion_types:
    image.setup_residue(0.0, 0.0, 0.0, ion_type)
# Out:
#  select>     43 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>   4783 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>    124 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>  39021 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>     11 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>      1 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS
#  select>      1 atoms have been selected out of   43984
#  IMAGE CENTERING ON FOR SOME ATOMS

# %%
# Now specify nonbonded cutoffs for solvated box
cutnb = min(solvator.box_dim/2, 12)
cutim = cutnb
ctofnb = cutnb - 1.0
ctonnb = cutnb - 3.0

# Another nbonds example
# CHARMM scripting: nbonds cutnb @cutnb cutim @cutim ctofnb @ctofnb ctonnb @ctonnb -
#        inbfrq -1 imgfrq -1
non_bonded_script = pycharmm.NonBondedScript(
    cutnb=cutnb, cutim=cutim, ctonnb=ctonnb, ctofnb=ctofnb,
    eps=1.0,
    cdie=True,
    atom=True, vatom=True,
    fswitch=True, vfswitch=True,
    inbfrq=-1, imgfrq=-1
)

# %%
# We want to fix the protein and ligands and minimize the solvent to "fit"
# Select everything but solvent and ions
cons_fix_atoms = pycharmm.SelectAtoms()
for segid in non_solvent_segids:
    cons_fix_atoms |= pycharmm.SelectAtoms(seg_id=segid)

# Minimize the solvent positions with periodic boundary conditions using steepest descents
ener_dict = sd_minimize(200, non_bonded_script, cons_fix_selection=cons_fix_atoms)
# Out:
#
#  CHARMM>     nbonds cutnb 12 -
#  CHARMM>     cutim 12 -
#  CHARMM>     ctonnb 9.0 -
#  CHARMM>     ctofnb 11.0 -
#  CHARMM>     eps 1.0 -
#  CHARMM>     cdie -
#  CHARMM>     atom -
#  CHARMM>     vatom -
#  CHARMM>     fswitch -
#  CHARMM>     vfswitch -
#  CHARMM>     inbfrq -1 -
#  CHARMM>     imgfrq -1
#
#  SELECTED IMAGES ATOMS BEING CENTERED ABOUT  0.000000  0.000000  0.000000
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  N1N1N1R1 has      63      21      21        1.52
#     2  N1Z0N1R1 has     684     228     228        1.51
#     3  N1P1N1R1 has      75      25      25        2.08
#     4  Z0N1N1R1 has     765     255     255        1.23
#     5  Z0Z0N1R1 has    6846    2284    2284        0.07
#     6  Z0P1N1R1 has     750     250     250        1.22
#     7  N1N1Z0R1 has     663     221     221        0.90
#     8  N1Z0Z0R1 has    6640    2208    2191        0.05
#     9  N1P1Z0R1 has     744     248     248        1.63
#    10  Z0N1Z0R1 has    6537    2181    2181        0.03
#    12  N1N1P1R1 has      57      19      19        0.95
#    13  N1Z0P1R1 has     682     228     228        0.93
#    14  N1P1P1R1 has      75      25      25        1.71
#  Total of68565 atoms and22632 groups and21496 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  9.000 CTOFNB = 11.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found  53117 exclusions and  13045 interactions(1-4)
#  <MAKGRP> found   4151 group exclusions.
#  <MAKGRP> found      0 image group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR  7959175 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#  WARNING: ATOMS LG01     1        GDP      HOB3     AND IO00     1        MG       MG       ONLY 1.48 A. APART
#  WARNING: ATOMS LG01     1        GDP      HO3'     AND WT00     78       TIP3     H2       ONLY 1.49 A. APART
#  == PRIMARY == SPACE FOR 11938782 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#  WARNING: ATOMS LG01     1        GDP      HOB3     AND IO00     1        MG       MG       ONLY 1.48 A. APART
#  WARNING: ATOMS LG01     1        GDP      HO3'     AND WT00     78       TIP3     H2       ONLY 1.49 A. APART
#  == PRIMARY == SPACE FOR 17908192 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#  WARNING: ATOMS LG01     1        GDP      HOB3     AND IO00     1        MG       MG       ONLY 1.48 A. APART
#  WARNING: ATOMS LG01     1        GDP      HO3'     AND WT00     78       TIP3     H2       ONLY 1.49 A. APART
#
#  General atom nonbond list generation found:
#  13011151 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    879802 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  7277414 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#   2256858 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#    224769 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>
#
#
#  SELECTED IMAGES ATOMS BEING CENTERED ABOUT  0.000000  0.000000  0.000000
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  N1N1N1R1 has      63      21      21        1.52
#     2  N1Z0N1R1 has     684     228     228        1.51
#     3  N1P1N1R1 has      75      25      25        2.08
#     4  Z0N1N1R1 has     765     255     255        1.23
#     5  Z0Z0N1R1 has    6846    2284    2284        0.07
#     6  Z0P1N1R1 has     750     250     250        1.22
#     7  N1N1Z0R1 has     663     221     221        0.90
#     8  N1Z0Z0R1 has    6640    2208    2191        0.05
#     9  N1P1Z0R1 has     744     248     248        1.63
#    10  Z0N1Z0R1 has    6537    2181    2181        0.03
#    12  N1N1P1R1 has      57      19      19        0.95
#    13  N1Z0P1R1 has     682     228     228        0.93
#    14  N1P1P1R1 has      75      25      25        1.71
#  Total of68565 atoms and22632 groups and21496 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  9.000 CTOFNB = 11.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are 13011151 atom  pairs and    66162 atom  exclusions.
#  There are        0 group pairs and     4151 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR 17908192 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
# /home/truman/crimm/crimm/Adaptors/pyCHARMMAdaptors.py:457: UserWarning: Atom fix constraint setup success: True
#   warnings.warn(f"Atom fix constraint setup success: {has_cons_fix}")
#  WARNING: ATOMS LG01     1        GDP      HOB3     AND IO00     1        MG       MG       ONLY 1.48 A. APART
#  WARNING: ATOMS LG01     1        GDP      HO3'     AND WT00     78       TIP3     H2       ONLY 1.49 A. APART
#
#  General atom nonbond list generation found:
#  11880792 ATOM PAIRS WERE FOUND FOR ATOM LIST
#
0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  SELECTED IMAGES ATOMS BEING CENTERED ABOUT  0.000000  0.000000  0.000000
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  N1N1N1R1 has      60      20      20        1.85
#     2  N1Z0N1R1 has     672     224     224        1.74
#     3  N1P1N1R1 has      72      24      24        2.42
#     4  Z0N1N1R1 has     753     251     251        1.45
#     5  Z0Z0N1R1 has    6705    2237    2237        0.07
#     6  Z0P1N1R1 has     750     250     250        1.45
#     7  N1N1Z0R1 has     615     205     205        1.22
#     8  N1Z0Z0R1 has    6526    2170    2154        0.00
#     9  N1P1Z0R1 has     738     246     246        1.85
#    10  Z0N1Z0R1 has    6512    2172    2172        0.31
#    12  N1N1P1R1 has      54      18      18        1.32
#    13  N1Z0P1R1 has     658     220     220        0.95
#    14  N1P1P1R1 has      69      23      23        1.98
#  Total of68168 atoms and22499 groups and21364 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSWItch  VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  9.000 CTOFNB = 11.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are 11925147 atom  pairs and    66162 atom  exclusions.
#  There are        0 group pairs and     4151 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR 17908192 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.75 Angstroms and starts with atom:    4784
#    Please check group boundary definitions.
#
#  General atom nonbond list generation found:
#  13055506 ATOM PAIRS WERE FOUND FOR ATOM LIST
#    884265 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR  7277414 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#   2214478 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#    223596 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    0.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:******* due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
# ENER ENR:  Eval#     ENERgy      Delta-E         GRMS
# ENER INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ENER CROSS:           CMAPs        PMF1D        PMF2D        PRIMO
# ENER EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# ENER IMAGES:        IMNBvdw       IMELec       IMHBnd       RXNField    EXTElec
#  ----------       ---------    ---------    ---------    ---------    ---------
# ENER>        0-147187.96659   2841.08936      3.29831
# ENER INTERN>     4543.94063   4154.73582     70.28278   2771.86291     43.61841
# ENER CROSS>      -138.69566      0.00000      0.00000      0.00000
# ENER EXTERN>    11607.99146-162901.11816      0.00000      0.00000      0.00000
# ENER IMAGES>     1038.97628  -8379.56107      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------

# %%
fetch_coords_from_charmm(model)
model
# Out:
# NGLWidget()
# <OrganizedModel model=5IGV Polypeptide(L)=1 Solvent=3 NucleosidePhosphate=1 Ligand=1 Ion=2 >
# 	│
# 	├───<Polypeptide(L) id=A Residues=298>
# 	├──────Description: Macrolide 2'-phosphotransferase II
# 	│
# 	├───<NucleosidePhosphate id=B Molecules=1>
# 	├──────Residue ID(s): GDP
# 	├──────Description: GUANOSINE-5'-DIPHOSPHATE
# 	│
# 	├───<Ligand id=C Molecules=1>
# 	├──────Residue ID(s): ZIT
# 	├──────Description: AZITHROMYCIN
# 	│
# 	├───<Ion id=D Residues=2>
# 	├──────Residue ID(s): CA, MG
# 	├──────Description: MAGNESIUM ION, CALCIUM ION
# 	│
# 	├───<Solvent id=E Residues=455>
# 	├──────Residue ID(s): HOH
# 	├──────Description: water
# 	│
# 	├───<Solvent id=WA Residues=9992>
# 	├──────Description: water
# 	│
# 	├───<Solvent id=WB Residues=2560>
# 	├──────Description: water
# 	│
# 	├───<Ion id=IA Residues=11>
# 	├──────Description: balancing ions (SOD)

# %%
pcm_write.coor_card(f'{PDBID}.crd')
pcm_write.psf_card(f'{PDBID}.psf')
# Out:
#
#  CHARMM>     write name 5igv.crd -
#  CHARMM>     coor card
#  VOPEN> Attempting to open::5igv.crd::
#  RDTITL>
#  RDTITL> No title read.
#  VCLOSE: Closing unit   91 with status "KEEP"
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     write name 5igv.psf -
#  CHARMM>     psf card
#  VOPEN> Attempting to open::5igv.psf::
#  RDTITL>
#  RDTITL> No title read.
#  VCLOSE: Closing unit   91 with status "KEEP"
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
